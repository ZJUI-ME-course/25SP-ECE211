# %%
import numpy as np
import matplotlib.pyplot as plt

# 定义频率范围
omega = np.linspace(0.01, 90, 10000)  # 从0到20弧度/秒，1000个点
# print(omega)
# 定义传递函数的分子和分母
numerator = 1
denominator = 1+1j*(omega*0.2-1/omega/0.05)

# 计算传递函数的值
H = numerator / denominator
# print(H)

# 幅度响应
magnitude = np.abs(H)
# print(magnitude)

# 相位响应
phase = np.angle(H, deg=True)  # 将相位转换为度
# print(phase)


# 绘制幅度响应
plt.figure(figsize=(8, 6))
plt.subplot(2, 1, 1)
plt.plot(omega, magnitude, label=r'$|H(\omega)|$')
plt.xlabel(r'$\omega$ (rad/s)')
plt.ylabel(r'$|H(\omega)|$')
plt.title(r'$|H(\omega)|$')

# plt.title(r'R=10')
plt.grid(True)
plt.legend()

# 绘制相位响应
plt.subplot(2, 1, 2)
plt.plot(omega, phase, label=r'$\angle H(\omega)$', color='orange')
plt.xlabel(r'$\omega$ (rad/s)')
plt.ylabel(r'$\angle H(\omega)$ (degrees)')
plt.title(r'Phase Response of $H(\omega)$')
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

# %%
from sympy import *
v=S('v')
q1=(v-4)/1+(v-0)/-3j-2

an=solve([q1],v)[v]
print(an-4)
# Out:
# 1.4 - 1.8*I

# %%
from sympy import *
from math import *
import numpy as np

import matplotlib.pyplot as plt
# omega=S('omega')
omega = np.linspace(-10, 10, 1000)  # 从0到20弧度/秒，1000个点
numerator=4*omega**2+(4*omega-omega**3)*1j
denominator=(4+omega**2)**2
H = numerator / denominator


magnitude = abs(H)
# print(magnitude)


# 相位响应
phase = np.angle(H, deg=True)/180*pi  # 将相位转换为度
print(phase[0])

plt.subplot(2, 1, 2)
plt.plot(omega, phase, label=r'$\angle H(\omega)$', color='orange')
plt.xlabel(r'$\omega$ (rad/s)')
plt.ylabel(r'$\angle H(\omega)$ (degrees)')
plt.title(r'Phase Response of $H(\omega)$')
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# 1.176005207095135

# %%
from sympy import *
from math import *
import numpy as np

import matplotlib.pyplot as plt
omega=S('omega')
omega = np.linspace(0, 10, 10000)  # 从0到20弧度/秒，1000个点
numerator=
denominator=
H = numerator / denominator


magnitude = abs(H)
print(magnitude)


# 相位响应
phase = np.angle(H, deg=True)/180*pi  # 将相位转换为度



print(phase)
plt.subplot(2, 1, 2)
plt.plot(omega, phase, label=r'$\angle H(\omega)$', color='orange')
plt.xlabel(r'$\omega$ (rad/s)')
plt.ylabel(r'$\angle H(\omega)$ (degrees)')
plt.title(r'Phase Response of $H(\omega)$')
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# [0.         0.00025002 0.00050005 ... 0.0961716  0.09616272 0.09615385]
# [ 0.          1.56979623  1.56879613 ... -1.17592826 -1.17596674
#  -1.17600521]

# %%
omega=S('omega')
c=-1j/omega/2

h=c/(1+omega*1j+c)
print(expand(h))
# Out:
# -0.5*I/(1.0*I*omega**2 + omega - 0.5*I)

# %%
sqrt(14**2+3**2)
# Out:
# 14.317821063276353

# %%
# 计算组合数 C(10, 5)
import math
combinations_count = math.factorial(10) // (math.factorial(5) * math.factorial(5))

print(combinations_count)  # 输出结果
# Out:
# 252

# %%
import numpy as np
import matplotlib.pyplot as plt

# 定义频率范围
omega = np.linspace(0.1, 90, 10000)  # 避免除以零，从0.1开始

# 定义传递函数的幅度
H = 1 / np.sqrt(1 + (0.2 * omega**21 - 20 / omega)**2)

# 绘制幅度响应
plt.figure(figsize=(8, 6))
plt.subplot(2, 1, 1)
plt.plot(omega, H, label=r'$|H(\omega)|$')  # 修正变量名
plt.xlabel(r'$\omega$ (rad/s)')
plt.ylabel(r'$|H(\omega)|$')
plt.title(r'Amplitude Response $|H(\omega)|$')
plt.grid(True)
plt.legend()

# 如果需要绘制相位响应，可以继续添加代码
# 这里只绘制幅度响应
plt.show()

# %%
# ft图像

import numpy as np
import matplotlib.pyplot as plt

# 定义时间范围
t = np.linspace(0, 4*np.pi, 1000)

# (a) f(t) = 1/2 + 1/2 cos(2t)
f_a = 0.5 + 0.5 * np.cos(2 * t)

# (b) f(t) = 2 + 2j sin(3t)
f_b_real = 2+np.sin(0*t)
f_b_img= 2 * np.sin(3 * t)
# (c) f(t) = 2 cos(2t) + 3 cos(3t)
f_c = 2 * np.cos(2 * t) + 3 * np.cos(3 * t)

# (d) f(t) = -2j sin(2t) + 2 cos(4t)
f_d_real =  + 2 * np.cos(4 * t)
f_d_img =-2 * np.sin(2 * t)
# 绘制图形
plt.figure(figsize=(12, 8))
plt.subplot(2, 2, 1)
plt.plot(t, f_a)
plt.title('(a) f(t) = 1/2 + 1/2 cos(2t)')
plt.xlabel('Time (s)')
plt.ylabel('f(t)')
plt.xlim(0,2*np.pi)

plt.subplot(2, 2, 2)
plt.plot(t, f_b_real, label='实部',linestyle='-')
plt.plot(t, f_b_img,label='虚部',linestyle='--')
plt.title('(b) f(t) = 2 + 2j sin(3t)')
plt.xlabel('Time (s)')
plt.ylabel('f(t)')
plt.xlim(0,4/3*pi)

plt.subplot(2, 2, 3)
plt.plot(t, f_c)
plt.title('(c) f(t) = 2 cos(2t) + 3 cos(3t)')
plt.xlabel('Time (s)')
plt.ylabel('f(t)')
plt.xlim(0,4*pi)


plt.subplot(2, 2, 4)
plt.plot(t, f_d_real, linestyle='-')
plt.plot(t, f_d_img,linestyle='--')
plt.title('(d) f(t) = -2j sin(2t) + 2 cos(4t)')
plt.xlabel('Time (s)')
plt.ylabel('f(t)')
plt.xlim(0,2*pi)



plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 生成时间变量 t
t = np.linspace(0, 2 * np.pi, 1000)

# 计算复数函数的实部和虚部
real_part = 2 * np.cos(4 * t)
imaginary_part = -2 * np.sin(2 * t)

# 绘制实部和虚部
plt.figure(figsize=(10, 6))
plt.plot(t, real_part, label='实部', linestyle='-')  # 实轴用实线
plt.plot(t, imaginary_part, label='虚部', linestyle='--')  # 虚轴用虚线

# 设置标签和标题
plt.xlabel('时间 t')
plt.ylabel('值')
plt.title('复数函数的实部和虚部')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /Users/a1234/Library/Python/3.9/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/a1234/Library/Python/3.9/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 22797 (\N{CJK UNIFIED IDEOGRAPH-590D}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/a1234/Library/Python/3.9/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/a1234/Library/Python/3.9/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 20989 (\N{CJK UNIFIED IDEOGRAPH-51FD}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt



t=np.linspace(0,4*pi,1000)


f1 = 0.5 + 0.5 * np.cos(2 * t)

plt.figure(figsize=(12,8))
plt.subplot(2,2,1)
plt.plot(t,f1)
plt.title('(d) f(t)=-2*cos')
plt.xlabel('Time ')
plt.ylabel('f(t)')
plt.xlim(0,2*np.pi)
# Out:
# (0.0, 6.283185307179586)
